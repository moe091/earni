# %%
import yfinance as yf
import psycopg2 as pg2
import pandas as pd
import pandas_market_calendars as mcal
import traceback
import sys
import os
from datetime import date, timedelta

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..', 'src')))
import database as db

nyse = mcal.get_calendar("NYSE")

# %%
def get_dates_for_ticker(ticker):
    """
    This method retrieves a list of all the tickers in the database.

    Returns:
        list: A list of all the tickers in the database.
    """

    conn = db.get_conn() # returns existing db connection, or creates one if needed

    with conn.cursor() as curs:
        try:
            curs.execute(f"SELECT ticker, date, time_of_report FROM earnings_reports WHERE ticker = '{ticker}'")
            dates = curs.fetchall()
        except Exception as e:
            print(f"Failed to get dates from database for ticker {ticker}", traceback.format_exc())
            raise e

    print(f"Retrieved {len(dates)} dates for ticker {ticker}")

    return dates

# %%
def populate_prices(ticker):
    """
        Populates relative stock prices for all earnings report records for a given ticker
        This is the root function called which handles every step to update all records for a given ticker

        1. Retrieve all earning report dates for the ticker [get_dates_for_ticker(ticker)]
        2. for each ER date:
            3. find all relative dates for the given date(-30d, +5d, etc) [find_relative_dates(report_date)]
            4. insert stock price data(open, close, high, etc) for each relative date into DB [insert_rel_dates]:
                5. insert_rel_dates first calls get_prices_for_dates(ticker, dates) to get prices at each date
                6. then it will call insert_prices(price_data) where it inserts all prices for each date into the DB
    """
        
    dates = get_dates_for_ticker(ticker)
    # dates includes the date of each earnings report for the given ticker
    # for each date in dates, find all 'relative_dates'. 
    # add the closing price for each relative_date to the database WHERE ticker=ticker AND date=date (undo the -1 day for pre-market!)
    # column names will be minus_1_day, minus_5_day, plus_1_day, plus_30_day, etc...

    
    #below is just for logging/debugging  
    for d in dates:
        rel_dates = find_relative_dates(d[1])
        insert_rel_dates(d, rel_dates)
    
    return rel_dates

# %%
def find_relative_dates(date):
    offsets = [1, 2, 3, 4, 5, 10, 20, 30]
    rel_dates = []
    end_date = date + timedelta(days=55)
    sched = nyse.schedule(start_date=date.strftime("%Y-%m-%d"), end_date=end_date.strftime("%Y-%m-%d"))
    
    for o in offsets:
        odate = sched.iloc[o].iloc[0].date()
        rel_dates.append((o, odate))

    
    #REVERSE!
    offsets = [-1, -2, -3, -4, -5, -10, -20, -30]
    start_date = date - timedelta(days=50)
    sched = nyse.schedule(start_date=start_date.strftime("%Y-%m-%d"), end_date=date.strftime("%Y-%m-%d"))

    for o in offsets:
        odate = sched.iloc[o].iloc[0].date()
        rel_dates.append((o, odate))


    #sched[1] is the day after 'date'. For post-market this makes sense. for pre-market we set 'date' back by 1 day, so sched[1] is
    #actually the same day as the report, which is what we want because thats the first trading session 'after' the report
    
    #sched.iloc[-1].iloc[0].date() is equal to date. The [-1] element is the original date passed into this func.
    #that corresponds to the -1 offset, because if it was an after-hours report then the last day before the report
    #IS the same day. If it was a pre-market

    return rel_dates

# %%
def get_prices_for_dates(ticker, dates, report_date):
    print(f"\n\n[get_prices_for_dates] ticker={ticker}, len(dates)={len(dates)}. report_date={report_date}")
    yt = yf.Ticker(ticker)
    print("start_date=", dates[0][1].strftime("%Y-%m-%d"))
    print("end_date=", dates[-1][1].strftime("%Y-%m-%d"))
    print("report_date=", report_date)

    # yt.history end date isn't inclusive, have to increase our last date by 1 day to include it
    end_date = dates[-1][1] + timedelta(days=1)
    prices = yt.history(start=dates[0][1].strftime("%Y-%m-%d"), end=end_date.strftime("%Y-%m-%d"))
    prices.index = prices.index.map(lambda d: d.date().strftime("%Y-%m-%d"))
    price_data = []
    
    for d in dates:
        d_string = d[1].strftime("%Y-%m-%d")
        price_point = {
            "ticker": ticker,
            "report_date": report_date,
            "date": d[1],
            "open": int(round(prices.loc[d_string]['Open'], 2) * 100),
            "close": int(round(prices.loc[d_string]['Close'], 2) * 100),
            "high": int(round(prices.loc[d_string]['High'], 2) * 100),
            "low": int(round(prices.loc[d_string]['Low'], 2) * 100),
            "volume": int(prices.loc[d_string]['Volume'])
        }
        price_data.append(price_point)
        #print(f"[{d[0]} :: {d_string}] {price_point}")

    return price_data

# %%
def insert_rel_dates(report, rel):
    """
        (realizing this func needs to be renamed... in fact, th
        Takes a single earnings report, and a list of relative dates, and retrieves necessary price data by calling
        get_prices_for_dates. Then inserts all of that data into the database by calling insert_price_data
    """
    dstring = "%Y-%m-%d"
    rel.sort(key=lambda d: d[0])
    #print(f"\nRetrieving and inserting relative date prices for {report}")
    price_data = get_prices_for_dates(report[0], rel, report[1])
    print("PRICE DATA: ", price_data)
    #for r in rel:
        # get closing price for ticker report[0] on r[1]
        #print(f"Updating {report[0]}_{report[1].strftime(dstring)}. {r[0]} days after report({r[1]}) is 420.69")

# %%
# Find all earnings reports for 'hut', 
# Find all relative dates for each earnings report(keeping market hours and weekends+holidays in mind),
# Retrieve Open, Close, High, Low, and Volume for each relative day, of each earnings_report,
# Insert all of the above price data into price_history table, alongside the ticker and the original report date
dates = populate_prices("hut")
# Out:
# Retrieved 12 dates for ticker hut
#
#
# [get_prices_for_dates] ticker=hut, len(dates)=16. report_date=2024-11-13
# start_date= 2024-10-03
# end_date= 2024-12-27
# report_date= 2024-11-13
# PRICE DATA:  [{'ticker': 'hut', 'report_date': datetime.date(2024, 11, 13), 'date': datetime.date(2024, 10, 3), 'open': 1181, 'close': 1173, 'high': 1202, 'low': 1144, 'volume': 2088900}, {'ticker': 'hut', 'report_date': datetime.date(2024, 11, 13), 'date': datetime.date(2024, 10, 17), 'open': 1281, 'close': 1267, 'high': 1336, 'low': 1254, 'volume': 4362600}, {'ticker': 'hut', 'report_date': datetime.date(2024, 11, 13), 'date': datetime.date(2024, 10, 31), 'open': 1803, 'close': 1579, 'high': 1822, 'low': 1578, 'volume': 7379400}, {'ticker': 'hut', 'report_date': datetime.date(2024, 11, 13), 'date': datetime.date(2024, 11, 7), 'open': 1847, 'close': 1897, 'high': 1942, 'low': 1830, 'volume': 6168400}, {'ticker': 'hut', 'report_date': datetime.date(2024, 11, 13), 'date': datetime.date(2024, 11, 8), 'open': 1911, 'close': 1957, 'high': 1996, 'low': 1891, 'volume': 4712400}, {'ticker': 'hut', 'report_date': datetime.date(2024, 11, 13), 'date': datetime.date(2024, 11, 11), 'open': 2134, 'close': 2459, 'high': 2532, 'low': 2057, 'volume': 13684700}, {'ticker': 'hut', 'report_date': datetime.date(2024, 11, 13), 'date': datetime.date(2024, 11, 12), 'open': 2380, 'close': 2386, 'high': 2440, 'low': 2281, 'volume': 8961500}, {'ticker': 'hut', 'report_date': datetime.date(2024, 11, 13), 'date': datetime.date(2024, 11, 13), 'open': 2547, 'close': 2478, 'high': 2847, 'low': 2434, 'volume': 17988400}, {'ticker': 'hut', 'report_date': datetime.date(2024, 11, 13), 'date': datetime.date(2024, 11, 14), 'open': 2610, 'close': 2314, 'high': 2645, 'low': 2312, 'volume': 7483100}, {'ticker': 'hut', 'report_date': datetime.date(2024, 11, 13), 'date': datetime.date(2024, 11, 15), 'open': 2426, 'close': 2526, 'high': 2574, 'low': 2344, 'volume': 7458300}, {'ticker': 'hut', 'report_date': datetime.date(2024, 11, 13), 'date': datetime.date(2024, 11, 18), 'open': 2519, 'close': 2504, 'high': 2585, 'low': 2410, 'volume': 8320600}, {'ticker': 'hut', 'report_date': datetime.date(2024, 11, 13), 'date': datetime.date(2024, 11, 19), 'open': 2482, 'close': 2532, 'high': 2538, 'low': 2367, 'volume': 8259200}, {'ticker': 'hut', 'report_date': datetime.date(2024, 11, 13), 'date': datetime.date(2024, 11, 20), 'open': 2615, 'close': 2446, 'high': 2649, 'low': 2389, 'volume': 9510800}, {'ticker': 'hut', 'report_date': datetime.date(2024, 11, 13), 'date': datetime.date(2024, 11, 27), 'open': 2505, 'close': 2845, 'high': 2878, 'low': 2461, 'volume': 12367300}, {'ticker': 'hut', 'report_date': datetime.date(2024, 11, 13), 'date': datetime.date(2024, 12, 12), 'open': 3027, 'close': 2732, 'high': 3126, 'low': 2712, 'volume': 18902800}, {'ticker': 'hut', 'report_date': datetime.date(2024, 11, 13), 'date': datetime.date(2024, 12, 27), 'open': 2401, 'close': 2232, 'high': 2417, 'low': 2212, 'volume': 4649400}]
#
#
# [get_prices_for_dates] ticker=hut, len(dates)=16. report_date=2024-08-13
# start_date= 2024-07-02
# end_date= 2024-09-25
# report_date= 2024-08-13
# PRICE DATA:  [{'ticker': 'hut', 'report_date': datetime.date(2024, 8, 13), 'date': datetime.date(2024, 7, 2), 'open': 1516, 'close': 1567, 'high': 1570, 'low': 1466, 'volume': 3999900}, {'ticker': 'hut', 'report_date': datetime.date(2024, 8, 13), 'date': datetime.date(2024, 7, 17), 'open': 2049, 'close': 1973, 'high': 2108, 'low': 1955, 'volume': 5959800}, {'ticker': 'hut', 'report_date': datetime.date(2024, 8, 13), 'date': datetime.date(2024, 7, 31), 'open': 1474, 'close': 1464, 'high': 1535, 'low': 1450, 'volume': 4700500}, {'ticker': 'hut', 'report_date': datetime.date(2024, 8, 13), 'date': datetime.date(2024, 8, 7), 'open': 1273, 'close': 1113, 'high': 1291, 'low': 1110, 'volume': 5042000}, {'ticker': 'hut', 'report_date': datetime.date(2024, 8, 13), 'date': datetime.date(2024, 8, 8), 'open': 1152, 'close': 1242, 'high': 1244, 'low': 1126, 'volume': 3593500}, {'ticker': 'hut', 'report_date': datetime.date(2024, 8, 13), 'date': datetime.date(2024, 8, 9), 'open': 1225, 'close': 1197, 'high': 1237, 'low': 1171, 'volume': 2853400}, {'ticker': 'hut', 'report_date': datetime.date(2024, 8, 13), 'date': datetime.date(2024, 8, 12), 'open': 1167, 'close': 1139, 'high': 1200, 'low': 1132, 'volume': 3396400}, {'ticker': 'hut', 'report_date': datetime.date(2024, 8, 13), 'date': datetime.date(2024, 8, 13), 'open': 1150, 'close': 1096, 'high': 1167, 'low': 1075, 'volume': 3710600}, {'ticker': 'hut', 'report_date': datetime.date(2024, 8, 13), 'date': datetime.date(2024, 8, 14), 'open': 1121, 'close': 1097, 'high': 1177, 'low': 1096, 'volume': 5569900}, {'ticker': 'hut', 'report_date': datetime.date(2024, 8, 13), 'date': datetime.date(2024, 8, 15), 'open': 1119, 'close': 1165, 'high': 1220, 'low': 1112, 'volume': 4216400}, {'ticker': 'hut', 'report_date': datetime.date(2024, 8, 13), 'date': datetime.date(2024, 8, 16), 'open': 1166, 'close': 1154, 'high': 1197, 'low': 1118, 'volume': 4038800}, {'ticker': 'hut', 'report_date': datetime.date(2024, 8, 13), 'date': datetime.date(2024, 8, 19), 'open': 1162, 'close': 1222, 'high': 1240, 'low': 1125, 'volume': 4150700}, {'ticker': 'hut', 'report_date': datetime.date(2024, 8, 13), 'date': datetime.date(2024, 8, 20), 'open': 1250, 'close': 1156, 'high': 1280, 'low': 1148, 'volume': 4620800}, {'ticker': 'hut', 'report_date': datetime.date(2024, 8, 13), 'date': datetime.date(2024, 8, 27), 'open': 1190, 'close': 1124, 'high': 1190, 'low': 1104, 'volume': 4774700}, {'ticker': 'hut', 'report_date': datetime.date(2024, 8, 13), 'date': datetime.date(2024, 9, 11), 'open': 1024, 'close': 1058, 'high': 1058, 'low': 975, 'volume': 4651000}, {'ticker': 'hut', 'report_date': datetime.date(2024, 8, 13), 'date': datetime.date(2024, 9, 25), 'open': 1248, 'close': 1253, 'high': 1313, 'low': 1244, 'volume': 5196100}]
#
#
# [get_prices_for_dates] ticker=hut, len(dates)=16. report_date=2024-05-15
# start_date= 2024-04-04
# end_date= 2024-06-28
# report_date= 2024-05-15
# PRICE DATA:  [{'ticker': 'hut', 'report_date': datetime.date(2024, 5, 15), 'date': datetime.date(2024, 4, 4), 'open': 988, 'close': 969, 'high': 1051, 'low': 961, 'volume': 4890200}, {'ticker': 'hut', 'report_date': datetime.date(2024, 5, 15), 'date': datetime.date(2024, 4, 18), 'open': 741, 'close': 788, 'high': 814, 'low': 738, 'volume': 2263900}, {'ticker': 'hut', 'report_date': datetime.date(2024, 5, 15), 'date': datetime.date(2024, 5, 2), 'open': 823, 'close': 816, 'high': 835, 'low': 800, 'volume': 1607900}, {'ticker': 'hut', 'report_date': datetime.date(2024, 5, 15), 'date': datetime.date(2024, 5, 9), 'open': 807, 'close': 815, 'high': 827, 'low': 790, 'volume': 1806100}, {'ticker': 'hut', 'report_date': datetime.date(2024, 5, 15), 'date': datetime.date(2024, 5, 10), 'open': 836, 'close': 799, 'high': 838, 'low': 788, 'volume': 1630300}, {'ticker': 'hut', 'report_date': datetime.date(2024, 5, 15), 'date': datetime.date(2024, 5, 13), 'open': 816, 'close': 787, 'high': 833, 'low': 785, 'volume': 1941600}, {'ticker': 'hut', 'report_date': datetime.date(2024, 5, 15), 'date': datetime.date(2024, 5, 14), 'open': 769, 'close': 779, 'high': 809, 'low': 767, 'volume': 3244300}, {'ticker': 'hut', 'report_date': datetime.date(2024, 5, 15), 'date': datetime.date(2024, 5, 15), 'open': 832, 'close': 883, 'high': 907, 'low': 809, 'volume': 4472900}, {'ticker': 'hut', 'report_date': datetime.date(2024, 5, 15), 'date': datetime.date(2024, 5, 16), 'open': 880, 'close': 892, 'high': 910, 'low': 860, 'volume': 3166700}, {'ticker': 'hut', 'report_date': datetime.date(2024, 5, 15), 'date': datetime.date(2024, 5, 17), 'open': 900, 'close': 916, 'high': 955, 'low': 877, 'volume': 2444500}, {'ticker': 'hut', 'report_date': datetime.date(2024, 5, 15), 'date': datetime.date(2024, 5, 20), 'open': 915, 'close': 994, 'high': 994, 'low': 914, 'volume': 2953700}, {'ticker': 'hut', 'report_date': datetime.date(2024, 5, 15), 'date': datetime.date(2024, 5, 21), 'open': 981, 'close': 969, 'high': 997, 'low': 957, 'volume': 2656200}, {'ticker': 'hut', 'report_date': datetime.date(2024, 5, 15), 'date': datetime.date(2024, 5, 22), 'open': 972, 'close': 985, 'high': 1061, 'low': 952, 'volume': 4344900}, {'ticker': 'hut', 'report_date': datetime.date(2024, 5, 15), 'date': datetime.date(2024, 5, 30), 'open': 903, 'close': 899, 'high': 928, 'low': 880, 'volume': 3129800}, {'ticker': 'hut', 'report_date': datetime.date(2024, 5, 15), 'date': datetime.date(2024, 6, 13), 'open': 1068, 'close': 1151, 'high': 1184, 'low': 1068, 'volume': 6971500}, {'ticker': 'hut', 'report_date': datetime.date(2024, 5, 15), 'date': datetime.date(2024, 6, 28), 'open': 1548, 'close': 1499, 'high': 1588, 'low': 1473, 'volume': 18681900}]
#
#
# [get_prices_for_dates] ticker=hut, len(dates)=16. report_date=2023-11-14
# start_date= 2023-10-04
# end_date= 2023-12-28
# report_date= 2023-11-14
# PRICE DATA:  [{'ticker': 'hut', 'report_date': datetime.date(2023, 11, 14), 'date': datetime.date(2023, 10, 4), 'open': 944, 'close': 944, 'high': 944, 'low': 893, 'volume': 1790440}, {'ticker': 'hut', 'report_date': datetime.date(2023, 11, 14), 'date': datetime.date(2023, 10, 18), 'open': 950, 'close': 894, 'high': 960, 'low': 885, 'volume': 1668060}, {'ticker': 'hut', 'report_date': datetime.date(2023, 11, 14), 'date': datetime.date(2023, 11, 1), 'open': 1100, 'close': 1100, 'high': 1110, 'low': 1055, 'volume': 1299280}, {'ticker': 'hut', 'report_date': datetime.date(2023, 11, 14), 'date': datetime.date(2023, 11, 8), 'open': 1150, 'close': 1125, 'high': 1160, 'low': 1100, 'volume': 1550300}, {'ticker': 'hut', 'report_date': datetime.date(2023, 11, 14), 'date': datetime.date(2023, 11, 9), 'open': 1210, 'close': 1120, 'high': 1300, 'low': 1100, 'volume': 3528200}, {'ticker': 'hut', 'report_date': datetime.date(2023, 11, 14), 'date': datetime.date(2023, 11, 10), 'open': 1140, 'close': 1085, 'high': 1154, 'low': 1075, 'volume': 2404440}, {'ticker': 'hut', 'report_date': datetime.date(2023, 11, 14), 'date': datetime.date(2023, 11, 13), 'open': 1055, 'close': 1015, 'high': 1060, 'low': 994, 'volume': 1977600}, {'ticker': 'hut', 'report_date': datetime.date(2023, 11, 14), 'date': datetime.date(2023, 11, 14), 'open': 960, 'close': 915, 'high': 1010, 'low': 875, 'volume': 3368420}, {'ticker': 'hut', 'report_date': datetime.date(2023, 11, 14), 'date': datetime.date(2023, 11, 15), 'open': 950, 'close': 1000, 'high': 1025, 'low': 885, 'volume': 2639940}, {'ticker': 'hut', 'report_date': datetime.date(2023, 11, 14), 'date': datetime.date(2023, 11, 16), 'open': 955, 'close': 930, 'high': 975, 'low': 915, 'volume': 2389760}, {'ticker': 'hut', 'report_date': datetime.date(2023, 11, 14), 'date': datetime.date(2023, 11, 17), 'open': 940, 'close': 950, 'high': 960, 'low': 925, 'volume': 1157080}, {'ticker': 'hut', 'report_date': datetime.date(2023, 11, 14), 'date': datetime.date(2023, 11, 20), 'open': 985, 'close': 990, 'high': 1010, 'low': 965, 'volume': 1739520}, {'ticker': 'hut', 'report_date': datetime.date(2023, 11, 14), 'date': datetime.date(2023, 11, 21), 'open': 960, 'close': 950, 'high': 969, 'low': 919, 'volume': 1975920}, {'ticker': 'hut', 'report_date': datetime.date(2023, 11, 14), 'date': datetime.date(2023, 11, 29), 'open': 1040, 'close': 980, 'high': 1055, 'low': 975, 'volume': 3340660}, {'ticker': 'hut', 'report_date': datetime.date(2023, 11, 14), 'date': datetime.date(2023, 12, 13), 'open': 836, 'close': 894, 'high': 900, 'low': 800, 'volume': 4297700}, {'ticker': 'hut', 'report_date': datetime.date(2023, 11, 14), 'date': datetime.date(2023, 12, 28), 'open': 1705, 'close': 1613, 'high': 1710, 'low': 1552, 'volume': 14097300}]
#
#
# [get_prices_for_dates] ticker=hut, len(dates)=16. report_date=2023-08-14
# start_date= 2023-07-03
# end_date= 2023-09-26
# report_date= 2023-08-14
# PRICE DATA:  [{'ticker': 'hut', 'report_date': datetime.date(2023, 8, 14), 'date': datetime.date(2023, 7, 3), 'open': 1635, 'close': 1760, 'high': 1805, 'low': 1625, 'volume': 2190940}, {'ticker': 'hut', 'report_date': datetime.date(2023, 8, 14), 'date': datetime.date(2023, 7, 18), 'open': 1880, 'close': 1900, 'high': 1950, 'low': 1835, 'volume': 2411960}, {'ticker': 'hut', 'report_date': datetime.date(2023, 8, 14), 'date': datetime.date(2023, 8, 1), 'open': 1725, 'close': 1695, 'high': 1730, 'low': 1614, 'volume': 2470820}, {'ticker': 'hut', 'report_date': datetime.date(2023, 8, 14), 'date': datetime.date(2023, 8, 8), 'open': 1580, 'close': 1635, 'high': 1655, 'low': 1510, 'volume': 2125460}, {'ticker': 'hut', 'report_date': datetime.date(2023, 8, 14), 'date': datetime.date(2023, 8, 9), 'open': 1664, 'close': 1530, 'high': 1675, 'low': 1525, 'volume': 3116960}, {'ticker': 'hut', 'report_date': datetime.date(2023, 8, 14), 'date': datetime.date(2023, 8, 10), 'open': 1550, 'close': 1525, 'high': 1622, 'low': 1520, 'volume': 1913680}, {'ticker': 'hut', 'report_date': datetime.date(2023, 8, 14), 'date': datetime.date(2023, 8, 11), 'open': 1500, 'close': 1485, 'high': 1550, 'low': 1470, 'volume': 1457260}, {'ticker': 'hut', 'report_date': datetime.date(2023, 8, 14), 'date': datetime.date(2023, 8, 14), 'open': 1415, 'close': 1390, 'high': 1435, 'low': 1330, 'volume': 1609180}, {'ticker': 'hut', 'report_date': datetime.date(2023, 8, 14), 'date': datetime.date(2023, 8, 15), 'open': 1395, 'close': 1318, 'high': 1435, 'low': 1312, 'volume': 1527200}, {'ticker': 'hut', 'report_date': datetime.date(2023, 8, 14), 'date': datetime.date(2023, 8, 16), 'open': 1277, 'close': 1285, 'high': 1324, 'low': 1245, 'volume': 2414680}, {'ticker': 'hut', 'report_date': datetime.date(2023, 8, 14), 'date': datetime.date(2023, 8, 17), 'open': 1250, 'close': 1210, 'high': 1260, 'low': 1200, 'volume': 1834220}, {'ticker': 'hut', 'report_date': datetime.date(2023, 8, 14), 'date': datetime.date(2023, 8, 18), 'open': 1135, 'close': 1200, 'high': 1220, 'low': 1125, 'volume': 2028960}, {'ticker': 'hut', 'report_date': datetime.date(2023, 8, 14), 'date': datetime.date(2023, 8, 21), 'open': 1200, 'close': 1195, 'high': 1220, 'low': 1170, 'volume': 1401220}, {'ticker': 'hut', 'report_date': datetime.date(2023, 8, 14), 'date': datetime.date(2023, 8, 28), 'open': 1145, 'close': 1140, 'high': 1160, 'low': 1125, 'volume': 1277560}, {'ticker': 'hut', 'report_date': datetime.date(2023, 8, 14), 'date': datetime.date(2023, 9, 12), 'open': 1100, 'close': 1070, 'high': 1175, 'low': 1060, 'volume': 2937640}, {'ticker': 'hut', 'report_date': datetime.date(2023, 8, 14), 'date': datetime.date(2023, 9, 26), 'open': 950, 'close': 925, 'high': 980, 'low': 921, 'volume': 930620}]
#
#
# [get_prices_for_dates] ticker=hut, len(dates)=16. report_date=2023-05-11
# start_date= 2023-03-30
# end_date= 2023-06-26
# report_date= 2023-05-11
# PRICE DATA:  [{'ticker': 'hut', 'report_date': datetime.date(2023, 5, 11), 'date': datetime.date(2023, 3, 30), 'open': 894, 'close': 869, 'high': 905, 'low': 860, 'volume': 1731240}, {'ticker': 'hut', 'report_date': datetime.date(2023, 5, 11), 'date': datetime.date(2023, 4, 14), 'open': 1115, 'close': 1065, 'high': 1120, 'low': 1019, 'volume': 2854140}, {'ticker': 'hut', 'report_date': datetime.date(2023, 5, 11), 'date': datetime.date(2023, 4, 28), 'open': 890, 'close': 894, 'high': 905, 'low': 875, 'volume': 1012880}, {'ticker': 'hut', 'report_date': datetime.date(2023, 5, 11), 'date': datetime.date(2023, 5, 5), 'open': 885, 'close': 940, 'high': 940, 'low': 880, 'volume': 1938700}, {'ticker': 'hut', 'report_date': datetime.date(2023, 5, 11), 'date': datetime.date(2023, 5, 8), 'open': 900, 'close': 894, 'high': 915, 'low': 865, 'volume': 1363180}, {'ticker': 'hut', 'report_date': datetime.date(2023, 5, 11), 'date': datetime.date(2023, 5, 9), 'open': 905, 'close': 890, 'high': 905, 'low': 865, 'volume': 2078940}, {'ticker': 'hut', 'report_date': datetime.date(2023, 5, 11), 'date': datetime.date(2023, 5, 10), 'open': 910, 'close': 915, 'high': 950, 'low': 894, 'volume': 1846720}, {'ticker': 'hut', 'report_date': datetime.date(2023, 5, 11), 'date': datetime.date(2023, 5, 11), 'open': 885, 'close': 840, 'high': 885, 'low': 819, 'volume': 1689300}, {'ticker': 'hut', 'report_date': datetime.date(2023, 5, 11), 'date': datetime.date(2023, 5, 12), 'open': 819, 'close': 869, 'high': 869, 'low': 819, 'volume': 875260}, {'ticker': 'hut', 'report_date': datetime.date(2023, 5, 11), 'date': datetime.date(2023, 5, 15), 'open': 885, 'close': 935, 'high': 944, 'low': 875, 'volume': 1239120}, {'ticker': 'hut', 'report_date': datetime.date(2023, 5, 11), 'date': datetime.date(2023, 5, 16), 'open': 919, 'close': 925, 'high': 940, 'low': 905, 'volume': 847380}, {'ticker': 'hut', 'report_date': datetime.date(2023, 5, 11), 'date': datetime.date(2023, 5, 17), 'open': 915, 'close': 1015, 'high': 1035, 'low': 915, 'volume': 2865340}, {'ticker': 'hut', 'report_date': datetime.date(2023, 5, 11), 'date': datetime.date(2023, 5, 18), 'open': 1000, 'close': 975, 'high': 1030, 'low': 940, 'volume': 1755860}, {'ticker': 'hut', 'report_date': datetime.date(2023, 5, 11), 'date': datetime.date(2023, 5, 25), 'open': 950, 'close': 919, 'high': 952, 'low': 905, 'volume': 698720}, {'ticker': 'hut', 'report_date': datetime.date(2023, 5, 11), 'date': datetime.date(2023, 6, 9), 'open': 1015, 'close': 955, 'high': 1015, 'low': 944, 'volume': 1088580}, {'ticker': 'hut', 'report_date': datetime.date(2023, 5, 11), 'date': datetime.date(2023, 6, 26), 'open': 1460, 'close': 1330, 'high': 1480, 'low': 1315, 'volume': 3398920}]
#
#
# [get_prices_for_dates] ticker=hut, len(dates)=16. report_date=2023-03-09
# start_date= 2023-01-26
# end_date= 2023-04-21
# report_date= 2023-03-09
# PRICE DATA:  [{'ticker': 'hut', 'report_date': datetime.date(2023, 3, 9), 'date': datetime.date(2023, 1, 26), 'open': 994, 'close': 943, 'high': 1015, 'low': 940, 'volume': 1555720}, {'ticker': 'hut', 'report_date': datetime.date(2023, 3, 9), 'date': datetime.date(2023, 2, 9), 'open': 1070, 'close': 915, 'high': 1080, 'low': 893, 'volume': 3212180}, {'ticker': 'hut', 'report_date': datetime.date(2023, 3, 9), 'date': datetime.date(2023, 2, 24), 'open': 860, 'close': 815, 'high': 869, 'low': 795, 'volume': 1798480}, {'ticker': 'hut', 'report_date': datetime.date(2023, 3, 9), 'date': datetime.date(2023, 3, 3), 'open': 775, 'close': 780, 'high': 805, 'low': 755, 'volume': 2117280}, {'ticker': 'hut', 'report_date': datetime.date(2023, 3, 9), 'date': datetime.date(2023, 3, 6), 'open': 785, 'close': 785, 'high': 840, 'low': 775, 'volume': 1640160}, {'ticker': 'hut', 'report_date': datetime.date(2023, 3, 9), 'date': datetime.date(2023, 3, 7), 'open': 795, 'close': 755, 'high': 800, 'low': 735, 'volume': 1913980}, {'ticker': 'hut', 'report_date': datetime.date(2023, 3, 9), 'date': datetime.date(2023, 3, 8), 'open': 755, 'close': 740, 'high': 765, 'low': 720, 'volume': 2233040}, {'ticker': 'hut', 'report_date': datetime.date(2023, 3, 9), 'date': datetime.date(2023, 3, 9), 'open': 730, 'close': 635, 'high': 743, 'low': 630, 'volume': 2077280}, {'ticker': 'hut', 'report_date': datetime.date(2023, 3, 9), 'date': datetime.date(2023, 3, 10), 'open': 650, 'close': 630, 'high': 670, 'low': 605, 'volume': 1682840}, {'ticker': 'hut', 'report_date': datetime.date(2023, 3, 9), 'date': datetime.date(2023, 3, 13), 'open': 670, 'close': 750, 'high': 805, 'low': 650, 'volume': 3755760}, {'ticker': 'hut', 'report_date': datetime.date(2023, 3, 9), 'date': datetime.date(2023, 3, 14), 'open': 875, 'close': 840, 'high': 925, 'low': 810, 'volume': 4137100}, {'ticker': 'hut', 'report_date': datetime.date(2023, 3, 9), 'date': datetime.date(2023, 3, 15), 'open': 840, 'close': 825, 'high': 855, 'low': 770, 'volume': 1989500}, {'ticker': 'hut', 'report_date': datetime.date(2023, 3, 9), 'date': datetime.date(2023, 3, 16), 'open': 825, 'close': 860, 'high': 875, 'low': 805, 'volume': 1407640}, {'ticker': 'hut', 'report_date': datetime.date(2023, 3, 9), 'date': datetime.date(2023, 3, 23), 'open': 915, 'close': 960, 'high': 990, 'low': 890, 'volume': 2780480}, {'ticker': 'hut', 'report_date': datetime.date(2023, 3, 9), 'date': datetime.date(2023, 4, 6), 'open': 810, 'close': 840, 'high': 850, 'low': 795, 'volume': 743140}, {'ticker': 'hut', 'report_date': datetime.date(2023, 3, 9), 'date': datetime.date(2023, 4, 21), 'open': 860, 'close': 844, 'high': 885, 'low': 832, 'volume': 2283420}]
#
#
# [get_prices_for_dates] ticker=hut, len(dates)=16. report_date=2022-08-11
# start_date= 2022-06-30
# end_date= 2022-09-23
# report_date= 2022-08-11
# PRICE DATA:  [{'ticker': 'hut', 'report_date': datetime.date(2022, 8, 11), 'date': datetime.date(2022, 6, 30), 'open': 675, 'close': 665, 'high': 700, 'low': 645, 'volume': 2095180}, {'ticker': 'hut', 'report_date': datetime.date(2022, 8, 11), 'date': datetime.date(2022, 7, 15), 'open': 795, 'close': 790, 'high': 810, 'low': 750, 'volume': 2489460}, {'ticker': 'hut', 'report_date': datetime.date(2022, 8, 11), 'date': datetime.date(2022, 7, 29), 'open': 1060, 'close': 1060, 'high': 1115, 'low': 1011, 'volume': 3931340}, {'ticker': 'hut', 'report_date': datetime.date(2022, 8, 11), 'date': datetime.date(2022, 8, 5), 'open': 1130, 'close': 1190, 'high': 1205, 'low': 1105, 'volume': 2527100}, {'ticker': 'hut', 'report_date': datetime.date(2022, 8, 11), 'date': datetime.date(2022, 8, 8), 'open': 1235, 'close': 1250, 'high': 1305, 'low': 1210, 'volume': 2798920}, {'ticker': 'hut', 'report_date': datetime.date(2022, 8, 11), 'date': datetime.date(2022, 8, 9), 'open': 1210, 'close': 1215, 'high': 1227, 'low': 1145, 'volume': 1823960}, {'ticker': 'hut', 'report_date': datetime.date(2022, 8, 11), 'date': datetime.date(2022, 8, 10), 'open': 1290, 'close': 1355, 'high': 1373, 'low': 1248, 'volume': 3574920}, {'ticker': 'hut', 'report_date': datetime.date(2022, 8, 11), 'date': datetime.date(2022, 8, 11), 'open': 1510, 'close': 1480, 'high': 1660, 'low': 1445, 'volume': 3643820}, {'ticker': 'hut', 'report_date': datetime.date(2022, 8, 11), 'date': datetime.date(2022, 8, 12), 'open': 1488, 'close': 1760, 'high': 1780, 'low': 1435, 'volume': 2991300}, {'ticker': 'hut', 'report_date': datetime.date(2022, 8, 11), 'date': datetime.date(2022, 8, 15), 'open': 1720, 'close': 1780, 'high': 1850, 'low': 1645, 'volume': 3901440}, {'ticker': 'hut', 'report_date': datetime.date(2022, 8, 11), 'date': datetime.date(2022, 8, 16), 'open': 1739, 'close': 1664, 'high': 1789, 'low': 1635, 'volume': 3002780}, {'ticker': 'hut', 'report_date': datetime.date(2022, 8, 11), 'date': datetime.date(2022, 8, 17), 'open': 1590, 'close': 1495, 'high': 1645, 'low': 1480, 'volume': 3339880}, {'ticker': 'hut', 'report_date': datetime.date(2022, 8, 11), 'date': datetime.date(2022, 8, 18), 'open': 1500, 'close': 1345, 'high': 1505, 'low': 1340, 'volume': 2099460}, {'ticker': 'hut', 'report_date': datetime.date(2022, 8, 11), 'date': datetime.date(2022, 8, 25), 'open': 1135, 'close': 1130, 'high': 1150, 'low': 1085, 'volume': 1442500}, {'ticker': 'hut', 'report_date': datetime.date(2022, 8, 11), 'date': datetime.date(2022, 9, 9), 'open': 1135, 'close': 1175, 'high': 1195, 'low': 1110, 'volume': 2978780}, {'ticker': 'hut', 'report_date': datetime.date(2022, 8, 11), 'date': datetime.date(2022, 9, 23), 'open': 873, 'close': 844, 'high': 894, 'low': 825, 'volume': 1611340}]
#
#
# [get_prices_for_dates] ticker=hut, len(dates)=16. report_date=2022-05-12
# start_date= 2022-03-31
# end_date= 2022-06-27
# report_date= 2022-05-12
# PRICE DATA:  [{'ticker': 'hut', 'report_date': datetime.date(2022, 5, 12), 'date': datetime.date(2022, 3, 31), 'open': 2905, 'close': 2760, 'high': 2945, 'low': 2750, 'volume': 1154220}, {'ticker': 'hut', 'report_date': datetime.date(2022, 5, 12), 'date': datetime.date(2022, 4, 14), 'open': 2350, 'close': 2210, 'high': 2350, 'low': 2195, 'volume': 863000}, {'ticker': 'hut', 'report_date': datetime.date(2022, 5, 12), 'date': datetime.date(2022, 4, 29), 'open': 1839, 'close': 1780, 'high': 1989, 'low': 1780, 'volume': 1454520}, {'ticker': 'hut', 'report_date': datetime.date(2022, 5, 12), 'date': datetime.date(2022, 5, 6), 'open': 1760, 'close': 1705, 'high': 1795, 'low': 1645, 'volume': 1526160}, {'ticker': 'hut', 'report_date': datetime.date(2022, 5, 12), 'date': datetime.date(2022, 5, 9), 'open': 1585, 'close': 1415, 'high': 1635, 'low': 1390, 'volume': 1898500}, {'ticker': 'hut', 'report_date': datetime.date(2022, 5, 12), 'date': datetime.date(2022, 5, 10), 'open': 1515, 'close': 1400, 'high': 1565, 'low': 1350, 'volume': 1502900}, {'ticker': 'hut', 'report_date': datetime.date(2022, 5, 12), 'date': datetime.date(2022, 5, 11), 'open': 1290, 'close': 1220, 'high': 1395, 'low': 1210, 'volume': 2988880}, {'ticker': 'hut', 'report_date': datetime.date(2022, 5, 12), 'date': datetime.date(2022, 5, 12), 'open': 1125, 'close': 1220, 'high': 1310, 'low': 1125, 'volume': 2490720}, {'ticker': 'hut', 'report_date': datetime.date(2022, 5, 12), 'date': datetime.date(2022, 5, 13), 'open': 1330, 'close': 1370, 'high': 1450, 'low': 1310, 'volume': 2268420}, {'ticker': 'hut', 'report_date': datetime.date(2022, 5, 12), 'date': datetime.date(2022, 5, 16), 'open': 1360, 'close': 1245, 'high': 1360, 'low': 1225, 'volume': 1931460}, {'ticker': 'hut', 'report_date': datetime.date(2022, 5, 12), 'date': datetime.date(2022, 5, 17), 'open': 1340, 'close': 1325, 'high': 1360, 'low': 1270, 'volume': 2094560}, {'ticker': 'hut', 'report_date': datetime.date(2022, 5, 12), 'date': datetime.date(2022, 5, 18), 'open': 1290, 'close': 1235, 'high': 1305, 'low': 1205, 'volume': 1951160}, {'ticker': 'hut', 'report_date': datetime.date(2022, 5, 12), 'date': datetime.date(2022, 5, 19), 'open': 1245, 'close': 1235, 'high': 1310, 'low': 1210, 'volume': 2043160}, {'ticker': 'hut', 'report_date': datetime.date(2022, 5, 12), 'date': datetime.date(2022, 5, 26), 'open': 1075, 'close': 1155, 'high': 1185, 'low': 1052, 'volume': 2436140}, {'ticker': 'hut', 'report_date': datetime.date(2022, 5, 12), 'date': datetime.date(2022, 6, 10), 'open': 955, 'close': 940, 'high': 990, 'low': 919, 'volume': 1936300}, {'ticker': 'hut', 'report_date': datetime.date(2022, 5, 12), 'date': datetime.date(2022, 6, 27), 'open': 869, 'close': 810, 'high': 880, 'low': 795, 'volume': 1911320}]
#
#
# [get_prices_for_dates] ticker=hut, len(dates)=16. report_date=2022-03-17
# start_date= 2022-02-03
# end_date= 2022-04-29
# report_date= 2022-03-17
# PRICE DATA:  [{'ticker': 'hut', 'report_date': datetime.date(2022, 3, 17), 'date': datetime.date(2022, 2, 3), 'open': 2955, 'close': 2890, 'high': 3040, 'low': 2875, 'volume': 941980}, {'ticker': 'hut', 'report_date': datetime.date(2022, 3, 17), 'date': datetime.date(2022, 2, 17), 'open': 3485, 'close': 3195, 'high': 3520, 'low': 3170, 'volume': 1597480}, {'ticker': 'hut', 'report_date': datetime.date(2022, 3, 17), 'date': datetime.date(2022, 3, 4), 'open': 2770, 'close': 2660, 'high': 2864, 'low': 2630, 'volume': 1099880}, {'ticker': 'hut', 'report_date': datetime.date(2022, 3, 17), 'date': datetime.date(2022, 3, 11), 'open': 2765, 'close': 2495, 'high': 2765, 'low': 2490, 'volume': 1202060}, {'ticker': 'hut', 'report_date': datetime.date(2022, 3, 17), 'date': datetime.date(2022, 3, 14), 'open': 2500, 'close': 2315, 'high': 2550, 'low': 2280, 'volume': 1912400}, {'ticker': 'hut', 'report_date': datetime.date(2022, 3, 17), 'date': datetime.date(2022, 3, 15), 'open': 2345, 'close': 2405, 'high': 2420, 'low': 2265, 'volume': 1672160}, {'ticker': 'hut', 'report_date': datetime.date(2022, 3, 17), 'date': datetime.date(2022, 3, 16), 'open': 2475, 'close': 2605, 'high': 2605, 'low': 2405, 'volume': 2494020}, {'ticker': 'hut', 'report_date': datetime.date(2022, 3, 17), 'date': datetime.date(2022, 3, 17), 'open': 2470, 'close': 2785, 'high': 2795, 'low': 2460, 'volume': 1318780}, {'ticker': 'hut', 'report_date': datetime.date(2022, 3, 17), 'date': datetime.date(2022, 3, 18), 'open': 2740, 'close': 2885, 'high': 2915, 'low': 2685, 'volume': 1738820}, {'ticker': 'hut', 'report_date': datetime.date(2022, 3, 17), 'date': datetime.date(2022, 3, 21), 'open': 2850, 'close': 2845, 'high': 2955, 'low': 2755, 'volume': 1081400}, {'ticker': 'hut', 'report_date': datetime.date(2022, 3, 17), 'date': datetime.date(2022, 3, 22), 'open': 2960, 'close': 2935, 'high': 3065, 'low': 2910, 'volume': 1344080}, {'ticker': 'hut', 'report_date': datetime.date(2022, 3, 17), 'date': datetime.date(2022, 3, 23), 'open': 2910, 'close': 2875, 'high': 3040, 'low': 2805, 'volume': 1589360}, {'ticker': 'hut', 'report_date': datetime.date(2022, 3, 17), 'date': datetime.date(2022, 3, 24), 'open': 2940, 'close': 3055, 'high': 3060, 'low': 2827, 'volume': 2332540}, {'ticker': 'hut', 'report_date': datetime.date(2022, 3, 17), 'date': datetime.date(2022, 3, 31), 'open': 2905, 'close': 2760, 'high': 2945, 'low': 2750, 'volume': 1154220}, {'ticker': 'hut', 'report_date': datetime.date(2022, 3, 17), 'date': datetime.date(2022, 4, 14), 'open': 2350, 'close': 2210, 'high': 2350, 'low': 2195, 'volume': 863000}, {'ticker': 'hut', 'report_date': datetime.date(2022, 3, 17), 'date': datetime.date(2022, 4, 29), 'open': 1839, 'close': 1780, 'high': 1989, 'low': 1780, 'volume': 1454520}]
#
#
# [get_prices_for_dates] ticker=hut, len(dates)=16. report_date=2021-11-11
# start_date= 2021-10-01
# end_date= 2021-12-27
# report_date= 2021-11-11
# PRICE DATA:  [{'ticker': 'hut', 'report_date': datetime.date(2021, 11, 11), 'date': datetime.date(2021, 10, 1), 'open': 4505, 'close': 4635, 'high': 4655, 'low': 4305, 'volume': 2107820}, {'ticker': 'hut', 'report_date': datetime.date(2021, 11, 11), 'date': datetime.date(2021, 10, 15), 'open': 5540, 'close': 6110, 'high': 6230, 'low': 5470, 'volume': 7255700}, {'ticker': 'hut', 'report_date': datetime.date(2021, 11, 11), 'date': datetime.date(2021, 10, 29), 'open': 6080, 'close': 6700, 'high': 6790, 'low': 5960, 'volume': 3497240}, {'ticker': 'hut', 'report_date': datetime.date(2021, 11, 11), 'date': datetime.date(2021, 11, 5), 'open': 7434, 'close': 7259, 'high': 7525, 'low': 6970, 'volume': 1727980}, {'ticker': 'hut', 'report_date': datetime.date(2021, 11, 11), 'date': datetime.date(2021, 11, 8), 'open': 7715, 'close': 7950, 'high': 8210, 'low': 7445, 'volume': 3356900}, {'ticker': 'hut', 'report_date': datetime.date(2021, 11, 11), 'date': datetime.date(2021, 11, 9), 'open': 8205, 'close': 7700, 'high': 8285, 'low': 7409, 'volume': 2608320}, {'ticker': 'hut', 'report_date': datetime.date(2021, 11, 11), 'date': datetime.date(2021, 11, 10), 'open': 7909, 'close': 7045, 'high': 8000, 'low': 6909, 'volume': 3020020}, {'ticker': 'hut', 'report_date': datetime.date(2021, 11, 11), 'date': datetime.date(2021, 11, 11), 'open': 7434, 'close': 7090, 'high': 7705, 'low': 7050, 'volume': 1975240}, {'ticker': 'hut', 'report_date': datetime.date(2021, 11, 11), 'date': datetime.date(2021, 11, 12), 'open': 7265, 'close': 7640, 'high': 7725, 'low': 6880, 'volume': 2977940}, {'ticker': 'hut', 'report_date': datetime.date(2021, 11, 11), 'date': datetime.date(2021, 11, 15), 'open': 7695, 'close': 7315, 'high': 7750, 'low': 7184, 'volume': 1691880}, {'ticker': 'hut', 'report_date': datetime.date(2021, 11, 11), 'date': datetime.date(2021, 11, 16), 'open': 6806, 'close': 6950, 'high': 7230, 'low': 6690, 'volume': 2054800}, {'ticker': 'hut', 'report_date': datetime.date(2021, 11, 11), 'date': datetime.date(2021, 11, 17), 'open': 7040, 'close': 6745, 'high': 7041, 'low': 6515, 'volume': 1738940}, {'ticker': 'hut', 'report_date': datetime.date(2021, 11, 11), 'date': datetime.date(2021, 11, 18), 'open': 6605, 'close': 6260, 'high': 6755, 'low': 5910, 'volume': 2431820}, {'ticker': 'hut', 'report_date': datetime.date(2021, 11, 11), 'date': datetime.date(2021, 11, 26), 'open': 5855, 'close': 6095, 'high': 6230, 'low': 5851, 'volume': 946120}, {'ticker': 'hut', 'report_date': datetime.date(2021, 11, 11), 'date': datetime.date(2021, 12, 10), 'open': 4700, 'close': 4390, 'high': 4745, 'low': 4325, 'volume': 1396980}, {'ticker': 'hut', 'report_date': datetime.date(2021, 11, 11), 'date': datetime.date(2021, 12, 27), 'open': 4500, 'close': 4405, 'high': 4575, 'low': 4338, 'volume': 1748500}]
#
#
# [get_prices_for_dates] ticker=hut, len(dates)=16. report_date=2021-08-12
# start_date= 2021-07-01
# end_date= 2021-09-24
# report_date= 2021-08-12
# PRICE DATA:  [{'ticker': 'hut', 'report_date': datetime.date(2021, 8, 12), 'date': datetime.date(2021, 7, 1), 'open': 2150, 'close': 2370, 'high': 2500, 'low': 2150, 'volume': 1016820}, {'ticker': 'hut', 'report_date': datetime.date(2021, 8, 12), 'date': datetime.date(2021, 7, 16), 'open': 2100, 'close': 1970, 'high': 2100, 'low': 1955, 'volume': 232980}, {'ticker': 'hut', 'report_date': datetime.date(2021, 8, 12), 'date': datetime.date(2021, 7, 30), 'open': 2250, 'close': 2365, 'high': 2425, 'low': 2210, 'volume': 438540}, {'ticker': 'hut', 'report_date': datetime.date(2021, 8, 12), 'date': datetime.date(2021, 8, 6), 'open': 2749, 'close': 2960, 'high': 3075, 'low': 2630, 'volume': 1505800}, {'ticker': 'hut', 'report_date': datetime.date(2021, 8, 12), 'date': datetime.date(2021, 8, 9), 'open': 3350, 'close': 3215, 'high': 3350, 'low': 3090, 'volume': 2249320}, {'ticker': 'hut', 'report_date': datetime.date(2021, 8, 12), 'date': datetime.date(2021, 8, 10), 'open': 3250, 'close': 3140, 'high': 3260, 'low': 2935, 'volume': 1034020}, {'ticker': 'hut', 'report_date': datetime.date(2021, 8, 12), 'date': datetime.date(2021, 8, 11), 'open': 3215, 'close': 3529, 'high': 3590, 'low': 3165, 'volume': 2010240}, {'ticker': 'hut', 'report_date': datetime.date(2021, 8, 12), 'date': datetime.date(2021, 8, 12), 'open': 3340, 'close': 3285, 'high': 3340, 'low': 3140, 'volume': 1219880}, {'ticker': 'hut', 'report_date': datetime.date(2021, 8, 12), 'date': datetime.date(2021, 8, 13), 'open': 3445, 'close': 3279, 'high': 3529, 'low': 3254, 'volume': 897720}, {'ticker': 'hut', 'report_date': datetime.date(2021, 8, 12), 'date': datetime.date(2021, 8, 16), 'open': 3350, 'close': 3300, 'high': 3490, 'low': 3210, 'volume': 1240740}, {'ticker': 'hut', 'report_date': datetime.date(2021, 8, 12), 'date': datetime.date(2021, 8, 17), 'open': 3245, 'close': 2955, 'high': 3333, 'low': 2930, 'volume': 1144820}, {'ticker': 'hut', 'report_date': datetime.date(2021, 8, 12), 'date': datetime.date(2021, 8, 18), 'open': 2917, 'close': 3020, 'high': 3218, 'low': 2880, 'volume': 886620}, {'ticker': 'hut', 'report_date': datetime.date(2021, 8, 12), 'date': datetime.date(2021, 8, 19), 'open': 2933, 'close': 3090, 'high': 3135, 'low': 2916, 'volume': 819840}, {'ticker': 'hut', 'report_date': datetime.date(2021, 8, 12), 'date': datetime.date(2021, 8, 26), 'open': 3390, 'close': 3370, 'high': 3525, 'low': 3335, 'volume': 728100}, {'ticker': 'hut', 'report_date': datetime.date(2021, 8, 12), 'date': datetime.date(2021, 9, 10), 'open': 5075, 'close': 4885, 'high': 5230, 'low': 4855, 'volume': 1500060}, {'ticker': 'hut', 'report_date': datetime.date(2021, 8, 12), 'date': datetime.date(2021, 9, 24), 'open': 4054, 'close': 4200, 'high': 4410, 'low': 4050, 'volume': 1547920}]
