# %%
import yfinance as yf
import psycopg2 as pg2
import pandas as pd
import pandas_market_calendars as mcal
import traceback
import sys
import os
from datetime import date, timedelta

sys.path.append(os.path.abspath(os.path.join(os.getcwd(), '..', '..', 'src')))
import database as db

nyse = mcal.get_calendar("NYSE")

# %%
def get_dates_for_ticker(ticker):
    """
    This method retrieves a list of all the tickers in the database.

    Returns:
        list: A list of all the tickers in the database.
    """

    conn = db.get_conn() # returns existing db connection, or creates one if needed

    with conn.cursor() as curs:
        try:
            curs.execute(f"SELECT ticker, date, time_of_report FROM earnings_reports WHERE ticker = '{ticker}'")
            dates = curs.fetchall()
        except Exception as e:
            print(f"Failed to get dates from database for ticker {ticker}", traceback.format_exc())
            raise e

    print(f"Retrieved {len(dates)} dates for ticker {ticker}")

    return dates

# %%
def get_closing_prices(dates):
    for d in dates:
        ticker, date, time = d
        print(f"\n{ticker} - {date} - {time}")
        if time == "Before Open":
            date = date - timedelta(days=1)
            print(f"new date = {date}")

# %%
def find_relative_dates(date):
    offsets = [1, 2, 3, 4, 5, 10, 20, 30]
    rel_dates = []
    end_date = date + timedelta(days=50)
    sched = nyse.schedule(start_date=date.strftime("%Y-%m-%d"), end_date=end_date.strftime("%Y-%m-%d"))
    
    for o in offsets:
        odate = sched.iloc[o].iloc[0].date()
        rel_dates.append((o, odate))

    
    #REVERSE!
    offsets = [-1, -2, -3, -4, -5, -10, -20, -30]
    start_date = date - timedelta(days=50)
    sched = nyse.schedule(start_date=start_date.strftime("%Y-%m-%d"), end_date=date.strftime("%Y-%m-%d"))

    for o in offsets:
        odate = sched.iloc[o].iloc[0].date()
        rel_dates.append((o, odate))


    #sched[1] is the day after 'date'. For post-market this makes sense. for pre-market we set 'date' back by 1 day, so sched[1] is
    #actually the same day as the report, which is what we want because thats the first trading session 'after' the report
    
    #sched.iloc[-1].iloc[0].date() is equal to date. The [-1] element is the original date passed into this func.
    #that corresponds to the -1 offset, because if it was an after-hours report then the last day before the report
    #IS the same day. If it was a pre-market

    return rel_dates

# %%
def populate_prices(ticker):
    """
        Populates relative stock prices for all earnings report records for a given ticker
    """
    def update_date(report):
        print("updating date: ", report)
        rel_dates = find_relative_dates(report[1])
        print(f"Adding {len(rel_dates)} relative dates to {report}. First rel_date is {rel_dates[0]}")
        insert_rel_dates(report, rel_dates)
        return rel_dates

        #for logging stuff. remove lines below this
        #rel_dates.sort(key=lambda r: r[0])
        #for r in rel_dates:
            #print(f"{r[0]} - {r[1]}")

        
    dates = get_dates_for_ticker(ticker)
    # dates includes the date of each earnings report for the given ticker
    # for each date in dates, find all 'relative_dates'. 
    # add the closing price for each relative_date to the database WHERE ticker=ticker AND date=date (undo the -1 day for pre-market!)
    # column names will be minus_1_day, minus_5_day, plus_1_day, plus_30_day, etc...

    
    #below is just for logging/debugging  
    rel_dates = update_date(dates[0]) #updating a single earnings report
    
    return rel_dates

# %%
def get_prices_for_dates(ticker, dates):
    print(f"[get_prices_for_dates] ticker={ticker}, len(dates)={len(dates)}")
    yt = yf.Ticker(ticker)
    print("start_date=", dates[0][1].strftime("%Y-%m-%d"))
    print("end_date=", dates[-1][1].strftime("%Y-%m-%d"))

    prices = yt.history(start=dates[0][1].strftime("%Y-%m-%d"), end=dates[-1][1].strftime("%Y-%m-%d"))
    for index, row in prices.iterrows():
        # I AM HERE: pull the datetime.date, open, close, high, low, and volume from each row.
        # match the values pulled from each row with the dates(days_relative, datetime.date) tuple
        # create a list of tuples with (days_relative, datetime.date, open, close, high, low, volume)
        # insert a row into the price_history table with:
        # ticker, earnings_report_date, open..., close..., high..., low..., volume...
        # NOTE :: Add a stock_splits column while we're at it?? Researcht h
        print(f"\n\nindex: {index} - {int(round(float(row[0]), 2) * 100)}\n{row}")

# %%
def insert_rel_dates(report, rel):
    dstring = "%Y-%m-%d"
    rel.sort(key=lambda d: d[0])
    print(f"\nRetrieving and inserting relative date prices for {report}")
    get_prices_for_dates(report[0], rel)
    #for r in rel:
        # get closing price for ticker report[0] on r[1]
        #print(f"Updating {report[0]}_{report[1].strftime(dstring)}. {r[0]} days after report({r[1]}) is 420.69")

# %%
dates = populate_prices("f")
# Out:
# Retrieved 47 dates for ticker f
# updating date:  ('f', datetime.date(2024, 10, 28), 'After Close')
# Adding 16 relative dates to ('f', datetime.date(2024, 10, 28), 'After Close'). First rel_date is (1, datetime.date(2024, 10, 29))
#
# Retrieving and inserting relative date prices for ('f', datetime.date(2024, 10, 28), 'After Close')
# [get_prices_for_dates] ticker=f, len(dates)=16
# start_date= 2024-09-17
# end_date= 2024-12-10
#
#
# index: 2024-09-17 00:00:00-04:00 - 1074
# Open            1.074402e+01
# High            1.099067e+01
# Low             1.067496e+01
# Close           1.075389e+01
# Volume          5.206860e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-17 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-18 00:00:00-04:00 - 1078
# Open            1.078349e+01
# High            1.110906e+01
# Low             1.077362e+01
# Close           1.083281e+01
# Volume          5.501730e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-18 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-19 00:00:00-04:00 - 1107
# Open            1.106960e+01
# High            1.115839e+01
# Low             1.072429e+01
# Close           1.077362e+01
# Volume          5.243640e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-19 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-20 00:00:00-04:00 - 1071
# Open            1.071442e+01
# High            1.073416e+01
# Low             1.054670e+01
# Close           1.073416e+01
# Volume          6.880910e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-20 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-23 00:00:00-04:00 - 1069
# Open            1.069469e+01
# High            1.077362e+01
# Low             1.056643e+01
# Close           1.076375e+01
# Volume          4.042130e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-23 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-24 00:00:00-04:00 - 1082
# Open            1.082295e+01
# High            1.085255e+01
# Low             1.066509e+01
# Close           1.072429e+01
# Volume          3.774630e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-24 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-25 00:00:00-04:00 - 1045
# Open            1.044804e+01
# High            1.044804e+01
# Low             1.018166e+01
# Close           1.028032e+01
# Volume          7.410960e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-25 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-26 00:00:00-04:00 - 1042
# Open            1.041845e+01
# High            1.060590e+01
# Low             1.041845e+01
# Close           1.053684e+01
# Volume          5.140850e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-26 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-27 00:00:00-04:00 - 1069
# Open            1.069469e+01
# High            1.084268e+01
# Low             1.061576e+01
# Close           1.063550e+01
# Volume          4.546960e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-27 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-30 00:00:00-04:00 - 1034
# Open            1.033952e+01
# High            1.046777e+01
# Low             1.029019e+01
# Close           1.041845e+01
# Volume          5.966290e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-30 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-01 00:00:00-04:00 - 1058
# Open            1.057630e+01
# High            1.067496e+01
# Low             1.043818e+01
# Close           1.060590e+01
# Volume          6.396300e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-01 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-02 00:00:00-04:00 - 1059
# Open            1.058617e+01
# High            1.058617e+01
# Low             1.029019e+01
# Close           1.033952e+01
# Volume          5.145740e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-02 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-03 00:00:00-04:00 - 1027
# Open            1.027046e+01
# High            1.032965e+01
# Low             1.019153e+01
# Close           1.030992e+01
# Volume          4.445830e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-03 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-04 00:00:00-04:00 - 1045
# Open            1.044804e+01
# High            1.046777e+01
# Low             1.030005e+01
# Close           1.042831e+01
# Volume          4.588300e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-04 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-07 00:00:00-04:00 - 1041
# Open            1.040858e+01
# High            1.046777e+01
# Low             1.030992e+01
# Close           1.034938e+01
# Volume          3.800910e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-07 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-08 00:00:00-04:00 - 1036
# Open            1.035925e+01
# High            1.043818e+01
# Low             1.024086e+01
# Close           1.034938e+01
# Volume          4.635570e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-08 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-09 00:00:00-04:00 - 1035
# Open            1.034938e+01
# High            1.053684e+01
# Low             1.030005e+01
# Close           1.047764e+01
# Volume          4.040700e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-09 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-10 00:00:00-04:00 - 1044
# Open            1.043818e+01
# High            1.055657e+01
# Low             1.039871e+01
# Close           1.053684e+01
# Volume          3.945830e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-10 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-11 00:00:00-04:00 - 1050
# Open            1.049737e+01
# High            1.065523e+01
# Low             1.048751e+01
# Close           1.057630e+01
# Volume          3.191570e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-11 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-14 00:00:00-04:00 - 1057
# Open            1.056643e+01
# High            1.081308e+01
# Low             1.051710e+01
# Close           1.077362e+01
# Volume          4.194020e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-14 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-15 00:00:00-04:00 - 1076
# Open            1.076375e+01
# High            1.087228e+01
# Low             1.067496e+01
# Close           1.069469e+01
# Volume          5.309710e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-15 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-16 00:00:00-04:00 - 1074
# Open            1.074402e+01
# High            1.103013e+01
# Low             1.074402e+01
# Close           1.088214e+01
# Volume          4.699640e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-16 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-17 00:00:00-04:00 - 1089
# Open            1.089201e+01
# High            1.098080e+01
# Low             1.079335e+01
# Close           1.092161e+01
# Volume          3.761720e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-17 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-18 00:00:00-04:00 - 1101
# Open            1.101040e+01
# High            1.102027e+01
# Low             1.089201e+01
# Close           1.095121e+01
# Volume          2.607490e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-18 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-21 00:00:00-04:00 - 1093
# Open            1.093147e+01
# High            1.101040e+01
# Low             1.071442e+01
# Close           1.073416e+01
# Volume          4.100860e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-21 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-22 00:00:00-04:00 - 1077
# Open            1.077362e+01
# High            1.100054e+01
# Low             1.077362e+01
# Close           1.096107e+01
# Volume          5.159760e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-22 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-23 00:00:00-04:00 - 1096
# Open            1.096107e+01
# High            1.108933e+01
# Low             1.087228e+01
# Close           1.091174e+01
# Volume          3.733540e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-23 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-24 00:00:00-04:00 - 1109
# Open            1.108933e+01
# High            1.109920e+01
# Low             1.092161e+01
# Close           1.108933e+01
# Volume          4.473640e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-24 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-25 00:00:00-04:00 - 1113
# Open            1.112879e+01
# High            1.117812e+01
# Low             1.087228e+01
# Close           1.092161e+01
# Volume          3.912070e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-25 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-28 00:00:00-04:00 - 1102
# Open            1.102027e+01
# High            1.123732e+01
# Low             1.097094e+01
# Close           1.121759e+01
# Volume          9.796700e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-28 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-29 00:00:00-04:00 - 1039
# Open            1.038885e+01
# High            1.040858e+01
# Low             1.004354e+01
# Close           1.027046e+01
# Volume          1.562280e+08
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-29 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-30 00:00:00-04:00 - 1026
# Open            1.026059e+01
# High            1.038885e+01
# Low             1.019153e+01
# Close           1.032965e+01
# Volume          4.885370e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-30 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-31 00:00:00-04:00 - 1029
# Open            1.029019e+01
# High            1.033952e+01
# Low             1.010273e+01
# Close           1.015206e+01
# Volume          7.209870e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-31 00:00:00-04:00, dtype: float64
#
#
# index: 2024-11-01 00:00:00-04:00 - 1019
# Open            1.019153e+01
# High            1.027046e+01
# Low             1.006327e+01
# Close           1.008300e+01
# Volume          4.347230e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-11-01 00:00:00-04:00, dtype: float64
#
#
# index: 2024-11-04 00:00:00-05:00 - 1009
# Open            1.009287e+01
# High            1.042831e+01
# Low             1.009287e+01
# Close           1.022113e+01
# Volume          5.532380e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-11-04 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-05 00:00:00-05:00 - 1019
# Open            1.019153e+01
# High            1.049737e+01
# Low             1.016193e+01
# Close           1.045791e+01
# Volume          4.930900e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-11-05 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-06 00:00:00-05:00 - 1080
# Open            1.080322e+01
# High            1.107946e+01
# Low             1.069469e+01
# Close           1.104000e+01
# Volume          1.007818e+08
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-11-06 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-07 00:00:00-05:00 - 1101
# Open                  11.01
# High                  11.11
# Low                   10.83
# Close                 10.96
# Volume          55407900.00
# Dividends              0.15
# Stock Splits           0.00
# Name: 2024-11-07 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-08 00:00:00-05:00 - 1093
# Open                  10.93
# High                  10.97
# Low                   10.86
# Close                 10.97
# Volume          45463400.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-08 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-11 00:00:00-05:00 - 1107
# Open                  11.07
# High                  11.32
# Low                   11.02
# Close                 11.23
# Volume          56630500.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-11 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-12 00:00:00-05:00 - 1114
# Open                  11.14
# High                  11.30
# Low                   10.95
# Close                 11.10
# Volume          44921400.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-12 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-13 00:00:00-05:00 - 1112
# Open                  11.12
# High                  11.17
# Low                   11.02
# Close                 11.10
# Volume          55150900.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-13 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-14 00:00:00-05:00 - 1113
# Open                  11.13
# High                  11.23
# Low                   11.02
# Close                 11.07
# Volume          56780900.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-14 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-15 00:00:00-05:00 - 1105
# Open                  11.05
# High                  11.15
# Low                   10.98
# Close                 11.01
# Volume          58895400.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-15 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-18 00:00:00-05:00 - 1105
# Open                  11.05
# High                  11.27
# Low                   11.03
# Close                 11.21
# Volume          47807600.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-18 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-19 00:00:00-05:00 - 1106
# Open                  11.06
# High                  11.32
# Low                   11.01
# Close                 11.05
# Volume          53227700.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-19 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-20 00:00:00-05:00 - 1101
# Open                  11.01
# High                  11.05
# Low                   10.61
# Close                 10.73
# Volume          68633300.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-20 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-21 00:00:00-05:00 - 1078
# Open                  10.78
# High                  10.85
# Low                   10.61
# Close                 10.80
# Volume          53409500.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-21 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-22 00:00:00-05:00 - 1081
# Open                  10.81
# High                  11.38
# Low                   10.80
# Close                 11.18
# Volume          82556700.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-22 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-25 00:00:00-05:00 - 1130
# Open                  11.30
# High                  11.52
# Low                   11.28
# Close                 11.40
# Volume          63469300.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-25 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-26 00:00:00-05:00 - 1116
# Open                  11.16
# High                  11.23
# Low                   11.04
# Close                 11.10
# Volume          47458800.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-26 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-27 00:00:00-05:00 - 1113
# Open                  11.13
# High                  11.26
# Low                   11.06
# Close                 11.10
# Volume          28474200.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-27 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-29 00:00:00-05:00 - 1116
# Open                  11.16
# High                  11.27
# Low                   11.12
# Close                 11.13
# Volume          28935200.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-29 00:00:00-05:00, dtype: float64
#
#
# index: 2024-12-02 00:00:00-05:00 - 1122
# Open                  11.22
# High                  11.25
# Low                   10.96
# Close                 10.98
# Volume          50034400.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-12-02 00:00:00-05:00, dtype: float64
#
#
# index: 2024-12-03 00:00:00-05:00 - 1099
# Open                  10.99
# High                  11.01
# Low                   10.82
# Close                 10.82
# Volume          43904300.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-12-03 00:00:00-05:00, dtype: float64
#
#
# index: 2024-12-04 00:00:00-05:00 - 1085
# Open                  10.85
# High                  10.87
# Low                   10.59
# Close                 10.74
# Volume          66780700.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-12-04 00:00:00-05:00, dtype: float64
#
#
# index: 2024-12-05 00:00:00-05:00 - 1064
# Open                  10.64
# High                  10.69
# Low                   10.39
# Close                 10.44
# Volume          68162000.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-12-05 00:00:00-05:00, dtype: float64
#
#
# index: 2024-12-06 00:00:00-05:00 - 1051
# Open                  10.51
# High                  10.60
# Low                   10.42
# Close                 10.51
# Volume          56227000.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-12-06 00:00:00-05:00, dtype: float64
#
#
# index: 2024-12-09 00:00:00-05:00 - 1056
# Open                  10.56
# High                  10.80
# Low                   10.53
# Close                 10.60
# Volume          53230100.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-12-09 00:00:00-05:00, dtype: float64
# /tmp/ipykernel_184597/2621265393.py:9: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"\n\nindex: {index} - {int(round(float(row[0]), 2) * 100)}\n{row}")

# %%
dates.sort(key=lambda d: d[0])
dates
# Out:
# [(-30, datetime.date(2024, 9, 17)),
#  (-20, datetime.date(2024, 10, 1)),
#  (-10, datetime.date(2024, 10, 15)),
#  (-5, datetime.date(2024, 10, 22)),
#  (-4, datetime.date(2024, 10, 23)),
#  (-3, datetime.date(2024, 10, 24)),
#  (-2, datetime.date(2024, 10, 25)),
#  (-1, datetime.date(2024, 10, 28)),
#  (1, datetime.date(2024, 10, 29)),
#  (2, datetime.date(2024, 10, 30)),
#  (3, datetime.date(2024, 10, 31)),
#  (4, datetime.date(2024, 11, 1)),
#  (5, datetime.date(2024, 11, 4)),
#  (10, datetime.date(2024, 11, 11)),
#  (20, datetime.date(2024, 11, 25)),
#  (30, datetime.date(2024, 12, 10))]

# %%
yt = yf.Ticker('f')

# %%
print("start_date=", dates[0][1].strftime("%Y-%m-%d"))
print("end_date=", dates[-1][1].strftime("%Y-%m-%d"))
# Out:
# start_date= 2024-09-17
# end_date= 2024-12-10

# %%
prices = yt.history(start=dates[0][1].strftime("%Y-%m-%d"), end=dates[-1][1].strftime("%Y-%m-%d"))
for index, row in prices.iterrows():
    print(f"\n\nindex: {index}\n{row}")
# Out:
# index: 2024-09-17 00:00:00-04:00
# Open            1.074402e+01
# High            1.099067e+01
# Low             1.067496e+01
# Close           1.075389e+01
# Volume          5.206860e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-17 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-18 00:00:00-04:00
# Open            1.078349e+01
# High            1.110906e+01
# Low             1.077362e+01
# Close           1.083281e+01
# Volume          5.501730e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-18 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-19 00:00:00-04:00
# Open            1.106960e+01
# High            1.115839e+01
# Low             1.072429e+01
# Close           1.077362e+01
# Volume          5.243640e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-19 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-20 00:00:00-04:00
# Open            1.071442e+01
# High            1.073416e+01
# Low             1.054670e+01
# Close           1.073416e+01
# Volume          6.880910e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-20 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-23 00:00:00-04:00
# Open            1.069469e+01
# High            1.077362e+01
# Low             1.056643e+01
# Close           1.076375e+01
# Volume          4.042130e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-23 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-24 00:00:00-04:00
# Open            1.082295e+01
# High            1.085255e+01
# Low             1.066509e+01
# Close           1.072429e+01
# Volume          3.774630e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-24 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-25 00:00:00-04:00
# Open            1.044804e+01
# High            1.044804e+01
# Low             1.018166e+01
# Close           1.028032e+01
# Volume          7.410960e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-25 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-26 00:00:00-04:00
# Open            1.041845e+01
# High            1.060590e+01
# Low             1.041845e+01
# Close           1.053684e+01
# Volume          5.140850e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-26 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-27 00:00:00-04:00
# Open            1.069469e+01
# High            1.084268e+01
# Low             1.061576e+01
# Close           1.063550e+01
# Volume          4.546960e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-27 00:00:00-04:00, dtype: float64
#
#
# index: 2024-09-30 00:00:00-04:00
# Open            1.033952e+01
# High            1.046777e+01
# Low             1.029019e+01
# Close           1.041845e+01
# Volume          5.966290e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-09-30 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-01 00:00:00-04:00
# Open            1.057630e+01
# High            1.067496e+01
# Low             1.043818e+01
# Close           1.060590e+01
# Volume          6.396300e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-01 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-02 00:00:00-04:00
# Open            1.058617e+01
# High            1.058617e+01
# Low             1.029019e+01
# Close           1.033952e+01
# Volume          5.145740e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-02 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-03 00:00:00-04:00
# Open            1.027046e+01
# High            1.032965e+01
# Low             1.019153e+01
# Close           1.030992e+01
# Volume          4.445830e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-03 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-04 00:00:00-04:00
# Open            1.044804e+01
# High            1.046777e+01
# Low             1.030005e+01
# Close           1.042831e+01
# Volume          4.588300e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-04 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-07 00:00:00-04:00
# Open            1.040858e+01
# High            1.046777e+01
# Low             1.030992e+01
# Close           1.034938e+01
# Volume          3.800910e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-07 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-08 00:00:00-04:00
# Open            1.035925e+01
# High            1.043818e+01
# Low             1.024086e+01
# Close           1.034938e+01
# Volume          4.635570e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-08 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-09 00:00:00-04:00
# Open            1.034938e+01
# High            1.053684e+01
# Low             1.030005e+01
# Close           1.047764e+01
# Volume          4.040700e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-09 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-10 00:00:00-04:00
# Open            1.043818e+01
# High            1.055657e+01
# Low             1.039871e+01
# Close           1.053684e+01
# Volume          3.945830e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-10 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-11 00:00:00-04:00
# Open            1.049737e+01
# High            1.065523e+01
# Low             1.048751e+01
# Close           1.057630e+01
# Volume          3.191570e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-11 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-14 00:00:00-04:00
# Open            1.056643e+01
# High            1.081308e+01
# Low             1.051710e+01
# Close           1.077362e+01
# Volume          4.194020e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-14 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-15 00:00:00-04:00
# Open            1.076375e+01
# High            1.087228e+01
# Low             1.067496e+01
# Close           1.069469e+01
# Volume          5.309710e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-15 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-16 00:00:00-04:00
# Open            1.074402e+01
# High            1.103013e+01
# Low             1.074402e+01
# Close           1.088214e+01
# Volume          4.699640e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-16 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-17 00:00:00-04:00
# Open            1.089201e+01
# High            1.098080e+01
# Low             1.079335e+01
# Close           1.092161e+01
# Volume          3.761720e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-17 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-18 00:00:00-04:00
# Open            1.101040e+01
# High            1.102027e+01
# Low             1.089201e+01
# Close           1.095121e+01
# Volume          2.607490e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-18 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-21 00:00:00-04:00
# Open            1.093147e+01
# High            1.101040e+01
# Low             1.071442e+01
# Close           1.073416e+01
# Volume          4.100860e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-21 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-22 00:00:00-04:00
# Open            1.077362e+01
# High            1.100054e+01
# Low             1.077362e+01
# Close           1.096107e+01
# Volume          5.159760e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-22 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-23 00:00:00-04:00
# Open            1.096107e+01
# High            1.108933e+01
# Low             1.087228e+01
# Close           1.091174e+01
# Volume          3.733540e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-23 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-24 00:00:00-04:00
# Open            1.108933e+01
# High            1.109920e+01
# Low             1.092161e+01
# Close           1.108933e+01
# Volume          4.473640e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-24 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-25 00:00:00-04:00
# Open            1.112879e+01
# High            1.117812e+01
# Low             1.087228e+01
# Close           1.092161e+01
# Volume          3.912070e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-25 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-28 00:00:00-04:00
# Open            1.102027e+01
# High            1.123732e+01
# Low             1.097094e+01
# Close           1.121759e+01
# Volume          9.796700e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-28 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-29 00:00:00-04:00
# Open            1.038885e+01
# High            1.040858e+01
# Low             1.004354e+01
# Close           1.027046e+01
# Volume          1.562280e+08
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-29 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-30 00:00:00-04:00
# Open            1.026059e+01
# High            1.038885e+01
# Low             1.019153e+01
# Close           1.032965e+01
# Volume          4.885370e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-30 00:00:00-04:00, dtype: float64
#
#
# index: 2024-10-31 00:00:00-04:00
# Open            1.029019e+01
# High            1.033952e+01
# Low             1.010273e+01
# Close           1.015206e+01
# Volume          7.209870e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-10-31 00:00:00-04:00, dtype: float64
#
#
# index: 2024-11-01 00:00:00-04:00
# Open            1.019153e+01
# High            1.027046e+01
# Low             1.006327e+01
# Close           1.008300e+01
# Volume          4.347230e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-11-01 00:00:00-04:00, dtype: float64
#
#
# index: 2024-11-04 00:00:00-05:00
# Open            1.009287e+01
# High            1.042831e+01
# Low             1.009287e+01
# Close           1.022113e+01
# Volume          5.532380e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-11-04 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-05 00:00:00-05:00
# Open            1.019153e+01
# High            1.049737e+01
# Low             1.016193e+01
# Close           1.045791e+01
# Volume          4.930900e+07
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-11-05 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-06 00:00:00-05:00
# Open            1.080322e+01
# High            1.107946e+01
# Low             1.069469e+01
# Close           1.104000e+01
# Volume          1.007818e+08
# Dividends       0.000000e+00
# Stock Splits    0.000000e+00
# Name: 2024-11-06 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-07 00:00:00-05:00
# Open                  11.01
# High                  11.11
# Low                   10.83
# Close                 10.96
# Volume          55407900.00
# Dividends              0.15
# Stock Splits           0.00
# Name: 2024-11-07 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-08 00:00:00-05:00
# Open                  10.93
# High                  10.97
# Low                   10.86
# Close                 10.97
# Volume          45463400.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-08 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-11 00:00:00-05:00
# Open                  11.07
# High                  11.32
# Low                   11.02
# Close                 11.23
# Volume          56630500.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-11 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-12 00:00:00-05:00
# Open                  11.14
# High                  11.30
# Low                   10.95
# Close                 11.10
# Volume          44921400.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-12 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-13 00:00:00-05:00
# Open                  11.12
# High                  11.17
# Low                   11.02
# Close                 11.10
# Volume          55150900.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-13 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-14 00:00:00-05:00
# Open                  11.13
# High                  11.23
# Low                   11.02
# Close                 11.07
# Volume          56780900.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-14 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-15 00:00:00-05:00
# Open                  11.05
# High                  11.15
# Low                   10.98
# Close                 11.01
# Volume          58895400.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-15 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-18 00:00:00-05:00
# Open                  11.05
# High                  11.27
# Low                   11.03
# Close                 11.21
# Volume          47807600.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-18 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-19 00:00:00-05:00
# Open                  11.06
# High                  11.32
# Low                   11.01
# Close                 11.05
# Volume          53227700.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-19 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-20 00:00:00-05:00
# Open                  11.01
# High                  11.05
# Low                   10.61
# Close                 10.73
# Volume          68633300.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-20 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-21 00:00:00-05:00
# Open                  10.78
# High                  10.85
# Low                   10.61
# Close                 10.80
# Volume          53409500.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-21 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-22 00:00:00-05:00
# Open                  10.81
# High                  11.38
# Low                   10.80
# Close                 11.18
# Volume          82556700.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-22 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-25 00:00:00-05:00
# Open                  11.30
# High                  11.52
# Low                   11.28
# Close                 11.40
# Volume          63469300.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-25 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-26 00:00:00-05:00
# Open                  11.16
# High                  11.23
# Low                   11.04
# Close                 11.10
# Volume          47458800.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-26 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-27 00:00:00-05:00
# Open                  11.13
# High                  11.26
# Low                   11.06
# Close                 11.10
# Volume          28474200.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-27 00:00:00-05:00, dtype: float64
#
#
# index: 2024-11-29 00:00:00-05:00
# Open                  11.16
# High                  11.27
# Low                   11.12
# Close                 11.13
# Volume          28935200.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-11-29 00:00:00-05:00, dtype: float64
#
#
# index: 2024-12-02 00:00:00-05:00
# Open                  11.22
# High                  11.25
# Low                   10.96
# Close                 10.98
# Volume          50034400.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-12-02 00:00:00-05:00, dtype: float64
#
#
# index: 2024-12-03 00:00:00-05:00
# Open                  10.99
# High                  11.01
# Low                   10.82
# Close                 10.82
# Volume          43904300.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-12-03 00:00:00-05:00, dtype: float64
#
#
# index: 2024-12-04 00:00:00-05:00
# Open                  10.85
# High                  10.87
# Low                   10.59
# Close                 10.74
# Volume          66780700.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-12-04 00:00:00-05:00, dtype: float64
#
#
# index: 2024-12-05 00:00:00-05:00
# Open                  10.64
# High                  10.69
# Low                   10.39
# Close                 10.44
# Volume          68162000.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-12-05 00:00:00-05:00, dtype: float64
#
#
# index: 2024-12-06 00:00:00-05:00
# Open                  10.51
# High                  10.60
# Low                   10.42
# Close                 10.51
# Volume          56227000.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-12-06 00:00:00-05:00, dtype: float64
#
#
# index: 2024-12-09 00:00:00-05:00
# Open                  10.56
# High                  10.80
# Low                   10.53
# Close                 10.60
# Volume          53230100.00
# Dividends              0.00
# Stock Splits           0.00
# Name: 2024-12-09 00:00:00-05:00, dtype: float64

# %%
index_map = {}
for i in prices.index:
    index_map[i] = i.date()

index_map
# Out:
# {Timestamp('2024-09-17 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 9, 17),
#  Timestamp('2024-09-18 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 9, 18),
#  Timestamp('2024-09-19 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 9, 19),
#  Timestamp('2024-09-20 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 9, 20),
#  Timestamp('2024-09-23 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 9, 23),
#  Timestamp('2024-09-24 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 9, 24),
#  Timestamp('2024-09-25 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 9, 25),
#  Timestamp('2024-09-26 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 9, 26),
#  Timestamp('2024-09-27 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 9, 27),
#  Timestamp('2024-09-30 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 9, 30),
#  Timestamp('2024-10-01 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 1),
#  Timestamp('2024-10-02 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 2),
#  Timestamp('2024-10-03 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 3),
#  Timestamp('2024-10-04 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 4),
#  Timestamp('2024-10-07 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 7),
#  Timestamp('2024-10-08 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 8),
#  Timestamp('2024-10-09 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 9),
#  Timestamp('2024-10-10 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 10),
#  Timestamp('2024-10-11 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 11),
#  Timestamp('2024-10-14 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 14),
#  Timestamp('2024-10-15 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 15),
#  Timestamp('2024-10-16 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 16),
#  Timestamp('2024-10-17 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 17),
#  Timestamp('2024-10-18 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 18),
#  Timestamp('2024-10-21 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 21),
#  Timestamp('2024-10-22 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 22),
#  Timestamp('2024-10-23 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 23),
#  Timestamp('2024-10-24 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 24),
#  Timestamp('2024-10-25 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 25),
#  Timestamp('2024-10-28 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 28),
#  Timestamp('2024-10-29 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 29),
#  Timestamp('2024-10-30 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 30),
#  Timestamp('2024-10-31 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 10, 31),
#  Timestamp('2024-11-01 00:00:00-0400', tz='America/New_York'): datetime.date(2024, 11, 1),
#  Timestamp('2024-11-04 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 4),
#  Timestamp('2024-11-05 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 5),
#  Timestamp('2024-11-06 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 6),
#  Timestamp('2024-11-07 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 7),
#  Timestamp('2024-11-08 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 8),
#  Timestamp('2024-11-11 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 11),
#  Timestamp('2024-11-12 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 12),
#  Timestamp('2024-11-13 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 13),
#  Timestamp('2024-11-14 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 14),
#  Timestamp('2024-11-15 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 15),
#  Timestamp('2024-11-18 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 18),
#  Timestamp('2024-11-19 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 19),
#  Timestamp('2024-11-20 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 20),
#  Timestamp('2024-11-21 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 21),
#  Timestamp('2024-11-22 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 22),
#  Timestamp('2024-11-25 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 25),
#  Timestamp('2024-11-26 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 26),
#  Timestamp('2024-11-27 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 27),
#  Timestamp('2024-11-29 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 11, 29),
#  Timestamp('2024-12-02 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 12, 2),
#  Timestamp('2024-12-03 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 12, 3),
#  Timestamp('2024-12-04 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 12, 4),
#  Timestamp('2024-12-05 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 12, 5),
#  Timestamp('2024-12-06 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 12, 6),
#  Timestamp('2024-12-09 00:00:00-0500', tz='America/New_York'): datetime.date(2024, 12, 9)}
